# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirapakit/SandBox/blob/main/cv2Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from IPython.display import clear_output, Image
import base64

# %%
img = cv2.imread("/content/chicken2.jpg")

scale_percent = 0.5

width = int(img.shape[1]*scale_percent)
height = int(img.shape[0]*scale_percent)
dimen = (width,height)

resize = cv2.resize(img,(dimen))

print(resize.shape)

cv2_imshow(img)
# Out:
# (91, 137, 3)
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F995A666850>

# %% [markdown]
# ### **QUESTION 1**

# %%
img = cv2.imread("/content/chicken.jpg")

width = img.shape[1]
height = img.shape[0]

if height > width:
    img2 = img[0:width,width:0]
else:
    img2 = img[0:height,0:height]
    
print("Image size is ",img2.shape)

cv2_imshow(img2)
#cv2.imwrite("newChicky.jpg",)
# Out:
# Image size is  (194, 194, 3)
# <PIL.Image.Image image mode=RGB size=194x194 at 0x7F9967BAE410>

# %% [markdown]
# ### **QUESTION 2**

# %%
cap = cv2.VideoCapture("/content/chicken_run.mp4")

"""
while (cap.isOpened()):
    check , frame = cap.read()

    if check == True:
        cv2.imshow("Output",frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else :
        break
"""
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH )
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT )
fps =  cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = frame_count/fps

print("Width = ",width)
print("Height = ",height)
print("FPS = ",fps)
print("Total frame = ",frame_count)
print("Duration = ",duration*1000,"ms")

cap.release()
cv2.destroyAllWindows()
# Out:
# Width =  640.0
# Height =  360.0
# FPS =  29.97002997002997
# Total frame =  992
# Duration =  33099.73333333333 ms

# %%
img = cv2.imread("/content/chicken.jpg")

cv2_imshow(img)

img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=260x194 at 0x7F9952E19F10>
